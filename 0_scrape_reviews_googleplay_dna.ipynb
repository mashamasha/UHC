# %%
import json
import pandas as pd
import requests
from collections import OrderedDict

searchman_key = "064b0ca7fa6f14c721f8f6cd69f8e94e"

# %% [markdown]
# #### Google play metadata

# %%
df_metadata = pd.read_csv("data/data_googleplay_dna.csv", header=None)
df_metadata.columns = ['name', 'id']; df_metadata
# Out:
#              name                        id
# 0  23andMe Health  com.twentythreeandme.app

# %%
app_names = list(df_metadata['name'])
app_ids = list(df_metadata['id'])

# %%
app_ids
# Out:
# ['com.twentythreeandme.app']

# %%
# Use Searchman API to get up to 100 reviews

def get_reviews(names, ids, sortby):
    sort = sortby
    count = 100

    app_reviews_all = {}
    for app_name, app_id in list(zip(names, ids)):
        print(app_id)
        url = "http://api.searchman.io/v1/android/us/app/reviews?" \
            "appId=%s&sort=%s&count=%s&apiKey=%s" % (app_id, sort, str(count), searchman_key)
        r = requests.get(url)
        reviews = json.loads(r.text)
        app_reviews_all[app_name] = reviews['data']
    return app_reviews_all

# %%
app_reviews_helpful = get_reviews(app_names, app_ids, "mosthelpful")
app_reviews_recent = get_reviews(app_names, app_ids, "mostrecent")
# Out:
# com.twentythreeandme.app
# com.twentythreeandme.app

# %%
with open("googleplay_reviews_recent_raw_dna.json", "w") as f:
    f.write(json.dumps(app_reviews_recent))
    
with open("googleplay_reviews_helpful_raw_dna.json", "w") as f:
    f.write(json.dumps(app_reviews_helpful))

# %%
app_reviews_helpful
# Out:
# {'23andMe Health': [{'id': 1548179804630,
#    'rating': 3,
#    'body': "the learning aspect of the app it's great, but it constantly won't pull up messages sent so that i can read them. some times they don't even pull up on the website as well. it's just a coding mess honestly.",
#    'reviewId': 'gp:AOqpTOGNnfT-V6GN59kAhgQ0wDQByTecpodB-M3dJ-cMVnIUMn_gYtillJVLvPVTdb13_S_3YYyPOO9E-bWzZ3E',
#    'version': '4.76.2',
#    'authorId': '110568310443405189483',
#    'author': 'Carrie Rios',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mD-5AfkvjKFkPn5LQZduP-_WZSDFkSKZTRTRfEh3Q',
#    'timestampEpoch': 1548179804,
#    'timestamp': '2019-01-22 17:56:44'},
#   {'id': 1548673102638,
#    'rating': 3,
#    'body': "This app would be awesome if I could also receive my messages through it. I have family members trying to contact me, and I can't see it unless I use the actual website. Please make messages an option on the app as well.",
#    'reviewId': 'gp:AOqpTOFIKHB8Ifr3xCcDPJDuHZ4vTwJiCZTqBWuLz_Lrx3uIyJEPeo8Iad1yQkxa7eJ3leRa5yLlswPTqiMl59I',
#    'version': '4.76.2',
#    'authorId': '104347726632168158977',
#    'author': 'Angie Q',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-rKxCgfqMnYM/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQOnJ-vHeisbcDCVDd7gdjnJO_-IKw/photo.jpg',
#    'timestampEpoch': 1548673102,
#    'timestamp': '2019-01-28 10:58:22'},
#   {'id': 1548664854468,
#    'rating': 3,
#    'body': "really, the only things to do are track your sample and answer research questions. don't know what would qualify it for 5 stars. did answer all possible questions though. if anyone is curious, there's 781 research questions.",
#    'reviewId': 'gp:AOqpTOGLUto_TdhSrgcgv5My9U0PqBHEe2bRovSJ-D9LEhshRWLX5Bzby26MVDJ-SuDcBt9aLr-BiPJ9YtosVk0',
#    'version': '4.76.2',
#    'authorId': '114330538500580587234',
#    'author': 'Felipe Pubillones',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mC4LEsRscELNHijjeUdMduv9QqmT20wywDcPl7HPw',
#    'timestampEpoch': 1548664854,
#    'timestamp': '2019-01-28 08:40:54'},
#   {'id': 1547924145631,
#    'rating': 4,
#    'body': "I'm amazed at the information we are able review about our DNA. However, the inability to access individuals that are matches to our DNA from the app is disheartening. I hope an update will include this ability .",
#    'reviewId': 'gp:AOqpTOFpzPzRolWjOFmLhqF2v2xA13uYo0IdWdPLSP15j6usool1HTEDoC76gWnC60SzxSWt22aw_dlPeZfP9lE',
#    'version': '4.76.2',
#    'authorId': '100100949923415890077',
#    'author': 'Kimberly Patterson',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-TPAKSGFKoHU/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQPFa7mEATP666wcZLkPOvL6n56pBg/photo.jpg',
#    'timestampEpoch': 1547924145,
#    'timestamp': '2019-01-19 18:55:45'},
#   {'id': 1548118688678,
#    'rating': 2,
#    'body': 'the app was streamlines and simple untill i had to enter my birthdate. instead of entering the numbers i had to scroll through the calander. im 25 thats 300 swipes. imagine a 40 or 60 year old.',
#    'reviewId': 'gp:AOqpTOFyCeDcNpwpWsLFZVed9VuZq9TZkwzWaxplouhTTqlMsH7T6stxJrGa0eseTGSdKFug73eIpweo2U7r5X4',
#    'version': '4.76.2',
#    'authorId': '113748656048990209430',
#    'author': 'Najee Abraham',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-lNipMVDdHPg/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQO932O-Wz1ZnN-P1QbgRpjwwQE5kw/photo.jpg',
#    'timestampEpoch': 1548118688,
#    'timestamp': '2019-01-22 00:58:08'},
#   {'id': 1548783633895,
#    'rating': 5,
#    'body': 'wow super interesting. I found family I never knew I had.. everybody should do this thing..',
#    'reviewId': 'gp:AOqpTOFcHeaOrYvblU9m71qDfSLQvbOP8w2TG69Sflh35dwQPr_gSGLzNXB-9bibNPAZURyy2da_JMp2CsxGIvU',
#    'version': '4.77.0',
#    'authorId': '103448064948120524610',
#    'author': 'John Chambers',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-0e_QZase9bo/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNjLMFGXH1aG6EDDXBm1S0bELDY8g/photo.jpg',
#    'timestampEpoch': 1548783633,
#    'timestamp': '2019-01-29 17:40:33'},
#   {'id': 1548759979285,
#    'rating': 4,
#    'body': 'very cool so far very interesting there could be a option to go back and change some answers but alll the info is really cool just a bit hesitant on my results cant wait !! definatly recomend to everyone',
#    'reviewId': 'gp:AOqpTOHBqpjZSlw_iTTWeaursKdojIQ8nI28pKJscel8rVvNLoUAJiXINxID_jI-UbNKoUUrDyEnoFZz0Eb90-s',
#    'version': '4.77.0',
#    'authorId': '113694810565094788519',
#    'author': 'Michael B. Ancira',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCV5stxTfdpNYKEkmOiXSSm9rrtp9IKmaVx9vCo',
#    'timestampEpoch': 1548759979,
#    'timestamp': '2019-01-29 11:06:19'},
#   {'id': 1548795002844,
#    'rating': 5,
#    'body': "This has been an amazing app. I have been able to add to my family tree even more thanks to the tools and information I'm using in thos app. Keep up the great work and I'm very excited about each and every new update. Thank you.",
#    'reviewId': 'gp:AOqpTOFl5lmWy_QCxanfbxxHjV21kMpaFGYiFd0aomF2NCt88W67xxAM1LkNjfPEA1KAsNULk1X_-DyNnEpusHg',
#    'version': '4.77.0',
#    'authorId': '114787371643728022024',
#    'author': 'Tommy Middle East and Balkan Combat Vet.',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAeAeY4_ww7233egFdNCB4Ua7I7t3rd9pfD67bI',
#    'timestampEpoch': 1548795002,
#    'timestamp': '2019-01-29 20:50:02'},
#   {'id': 1547921349420,
#    'rating': 1,
#    'body': 'Still waiting for results past the 8 week mark. Ancestry DNA only took a week. Professional Genealogists have told me 23andMe is the worst with regard to providing results. Update: after researching for over a year - they were right.',
#    'reviewId': 'gp:AOqpTOF6M_0hoy3lLDYJRDfqxXUhhhqXzaRoH7-l8tmENybykJhLWcwCGupUJD2wGra3twRiyK_snNtHcbllq2E',
#    'version': '4.76.2',
#    'authorId': '103154248284731591487',
#    'author': 'David Shain',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mALDUaZCyEsBKXTChpVNsvVe5_KgKnqDfAWFlroOg',
#    'timestampEpoch': 1547921349,
#    'timestamp': '2019-01-19 18:09:09'},
#   {'id': 1548785253793,
#    'rating': 4,
#    'body': 'participating with 23andMe has been a very satisfying and fulfilling, all around, wholesome, experience. Although, it is curious, as to why, the blood type group and/or Rh factor, is no longer available as information provided to 23andMe participant results....??',
#    'reviewId': 'gp:AOqpTOEn6pYwqOJ6INGK52ZRDl-tKJyHiyAOIWwOtPnwJFXUFIuSaxQHvIp52H6zIbeqYo-ZfYCP4pXg1KdDg28',
#    'version': '4.76.2',
#    'authorId': '110026380947936293890',
#    'author': 'Racheal Bandhu',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-EvHJJWVsaFE/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQOIkeAO0F7nrT3yMn441z0ea_y1EQ/photo.jpg',
#    'timestampEpoch': 1548785253,
#    'timestamp': '2019-01-29 18:07:33'},
#   {'id': 1548064210199,
#    'rating': 5,
#    'body': "This app is seriously fun to use and it's fun to learn new things about myself and honestly cultures I didn't know about. Can't wait to learn even more! 👍",
#    'reviewId': 'gp:AOqpTOGJ7Q5FgjYDYXSlYFbrYg6QFtG4e7IZC2J6NSHJOuLqeCf6DIbNwXtkkua_JUdsuja9FApcX8Ejs5LFkq0',
#    'version': '4.76.2',
#    'authorId': '107896925578441278890',
#    'author': 'John Adkins',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-Ki97y2eDQ24/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQPtPEo6JDaz039AgcgZbCeDFMF2lA/photo.jpg',
#    'timestampEpoch': 1548064210,
#    'timestamp': '2019-01-21 09:50:10'},
#   {'id': 1548540963132,
#    'rating': 5,
#    'body': 'great app. so interesting to see my roots. I ordered 1 for my mom and dad so lets see what theirs shows up as! happy with my purchase',
#    'reviewId': 'gp:AOqpTOHfLoekV16J3-xdngz4wzmlrfvkUfnFgPDlex2HEzrMBlbMwSIuIpRGBG4fF_ZmU-gVchXQxGOgkHvSkHI',
#    'version': '4.76.2',
#    'authorId': '117126382994609831623',
#    'author': 'Daniel Stanciu',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-_KrfLQeZcGg/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQOmNQnTR1pZk_KK8thp1S3u5uFdoQ/photo.jpg',
#    'timestampEpoch': 1548540963,
#    'timestamp': '2019-01-26 22:16:03'},
#   {'id': 1548451488621,
#    'rating': 5,
#    'body': 'Overall, very excited with all the features. Would like to know more about the ethnicities and get more of a percentage breakdown of an Eastern European ancestry',
#    'reviewId': 'gp:AOqpTOEkHRupn-6Lbsfy0cNMdaVC-sMN0ySTSdxQcLBtTiUb0yO0WF0yCX_rX2l71Z4o1FTxg8KepSMiGWpvxGk',
#    'version': '4.76.2',
#    'authorId': '102521592854929844023',
#    'author': 'Lina Kisieliūtė',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBilv1hGjM0-2p0tj0hU7l7OciTF5rIf-dSTlY2',
#    'timestampEpoch': 1548451488,
#    'timestamp': '2019-01-25 21:24:48'},
#   {'id': 1548304275573,
#    'rating': 4,
#    'body': "So far so good! I'm totally psyched to get my results. I keep telling people I'm not really a Neanderthal, now I'll have proof!",
#    'reviewId': 'gp:AOqpTOGNH81gx2aj8bIvow1XIfkfDHK9a5cDqygwkoupmQrDPBLt8D_ftpB2f83DijKerMIFhQjhoHcUf1gyGLo',
#    'version': '4.76.2',
#    'authorId': '111878683704573144192',
#    'author': 'Jeremy McQuain',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-7oEo4JvCz5A/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQO0BxvI-1XpVkatFSvyGGErwZZAYg/photo.jpg',
#    'timestampEpoch': 1548304275,
#    'timestamp': '2019-01-24 04:31:15'},
#   {'id': 1548617603756,
#    'rating': 4,
#    'body': "Would like more detail on lineage. Some very broad. Can't say I really learned anything.",
#    'reviewId': 'gp:AOqpTOH2cxyXDE-VwkldzrB-doeA6du2LghTxBM2H6cno9NxVuK5W-yQ60HHsQ55IY6c7p43IQN5BqkhgHjeiiE',
#    'version': '4.76.2',
#    'authorId': '112545831652952485321',
#    'author': 'Ted Ryder',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-orjSVwCfUaM/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQMxGpDHf9XVFlokYNxVpw7PcZY51w/photo.jpg',
#    'timestampEpoch': 1548617603,
#    'timestamp': '2019-01-27 19:33:23'},
#   {'id': 1548023640677,
#    'rating': 1,
#    'body': 'The app doesn\'t work. It shows an "oops something went wrong" and asks to retry. Is there a Note 9 direct error',
#    'reviewId': 'gp:AOqpTOHxFXhtWi4MPWYYJF_bD1X-0W_HYQpLaa4aftXnNuwIxfR9XrEgpf0v8n8BhrKrNsQgvS6uE-FZQlXoVK4',
#    'version': '4.76.2',
#    'authorId': '106879034209883256551',
#    'author': 'Luis R.',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCbaRtxIU5q30hnV3SUa9e4J82cFHXLI5J6OROYkXc',
#    'timestampEpoch': 1548023640,
#    'timestamp': '2019-01-20 22:34:00'},
#   {'id': 1548263508812,
#    'rating': 5,
#    'body': "Love the app. Id like to be able to see my raw genetic data without having to go to the site, but otherwise it's a pretty comprehensive app!",
#    'reviewId': 'gp:AOqpTOG_NzEQUb2pklAJ3r48Ws27j_3sbSuaNTEGBU4bzXlm8vEu2S8qKq48IwZpoXvl7KmuzKMN05hBWJNkbUw',
#    'version': '4.76.2',
#    'authorId': '105665281666634832258',
#    'author': 'Kristina Dickinson Kremer',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBCSJ9zcSAzN_CP2rI2N1TRqSI7SGb_BxTvw1asOz8',
#    'timestampEpoch': 1548263508,
#    'timestamp': '2019-01-23 17:11:48'},
#   {'id': 1548743785646,
#    'rating': 5,
#    'body': "Since receiving my results, I'm extremely excited when I receive a email regarding updates on my family's history. Thank you☺",
#    'reviewId': 'gp:AOqpTOFzjcUcim-RIoHRGALYRchjW96G-eG976mQtCZ2VTbc4in-SEvEv8cFgzVDgXa2EpOI6GRoY_DYvuhEVpY',
#    'version': '4.77.0',
#    'authorId': '102953334026836827808',
#    'author': 'Sarah C-P',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBOMIyvoBGgVrOOMcXzvEhBhUFKMage47atzu54WQI',
#    'timestampEpoch': 1548743785,
#    'timestamp': '2019-01-29 06:36:25'},
#   {'id': 1548211828567,
#    'rating': 5,
#    'body': "I've had a great time exploring my DNA with this app. The flow could be a little more user friendly but all of the areas work when you find what you're looking for. Still Five Star worthy!",
#    'reviewId': 'gp:AOqpTOHIJE087WT9a4iczhLM79h-UlExicMfIjWjwlQPRH09Y1gW-HiOP9m5J-9kkaLBB_nAKJDobSjVi8vv9FQ',
#    'version': '4.76.2',
#    'authorId': '109539459032590134720',
#    'author': 'M Conrad',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mDXzDMJa0yc22nAT74JbQvlqzfUFoFcvx0R_7SkBA',
#    'timestampEpoch': 1548211828,
#    'timestamp': '2019-01-23 02:50:28'},
#   {'id': 1547927855557,
#    'rating': 3,
#    'body': 'Great potential, IF the application loads. Mine ALWAYS starts with, "oops...reload the app." Once, I reload once or twice the app. finally works and the information provided is very informative! if it worked right...5 stars easily.',
#    'reviewId': 'gp:AOqpTOHw_xANcgr4XAtLLo7spXAGxFYcVRTEPEBRNsqYpsjw-kwu5-i7heqJVRtdZ8k2dn_rqQjQhJ2UAVixyEA',
#    'version': '4.76.2',
#    'authorId': '101506698385419995566',
#    'author': 'Dennis Adams',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBJ5tkBXA8JCWRj5s8HsVH26foB_5HdfVaNO48a4w',
#    'timestampEpoch': 1547927855,
#    'timestamp': '2019-01-19 19:57:35'},
#   {'id': 1547943782298,
#    'rating': 5,
#    'body': "I love the fact that I can contribute to humanity's overall wellbeing and health. Company employees are friendly and practices are easily laid out in front of you. I feel like 23andMe is doing a great service. :)",
#    'reviewId': 'gp:AOqpTOGfNl-quuibZcUWDNEjiYdQ9F0o9RZOkh0uPH1J-k2292OHvNbUKeqJPBkNNju6gjWv003uZmPzDG59RIY',
#    'version': '4.76.2',
#    'authorId': '106664728498210333364',
#    'author': 'Knives Wolfram',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mDY7oFB24fXRD4e2E2Nw_gZeKbNIQDuJqRh6BKgkQ',
#    'timestampEpoch': 1547943782,
#    'timestamp': '2019-01-20 00:23:02'},
#   {'id': 1548028934962,
#    'rating': 4,
#    'body': "I like both the website and the app, but it's weird that the messaging systems are separate.",
#    'reviewId': 'gp:AOqpTOGwPG6htu_0_6cfOBb8yFNG92BOmGo3FdhfX-FXIq3GaeyfN5HMX6u1im6PvFy6wfLYJBTv3OW1Q_5IApc',
#    'version': '4.76.2',
#    'authorId': '101198044314700878969',
#    'author': 'Christina Lynn Schneider',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mC0fKC8oKohMrsHKWwsyxl0lBD886vYctZK7YcG',
#    'timestampEpoch': 1548028934,
#    'timestamp': '2019-01-21 00:02:14'},
#   {'id': 1548360387441,
#    'rating': 1,
#    'body': 'i dont know whats going on, but i cannot log in anymore...is there a reason for this?',
#    'reviewId': 'gp:AOqpTOEOGpTFwRqrwpXbxpcj49Jc-DvW5_5-NY2--qHfVdL7OwH138JQSy-sKMUGI60FhIzCOgddaHjftFQg9aw',
#    'version': '4.76.2',
#    'authorId': '106207867546326962531',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-K1LKs3eK8ko/AAAAAAAAAAI/AAAAAAAAAAA/QGIR_P9mtKI/photo.jpg',
#    'timestampEpoch': 1548360387,
#    'timestamp': '2019-01-24 20:06:27'},
#   {'id': 1548012874471,
#    'rating': 5,
#    'body': "Love it..especially since the last update, it is informative and gives you something you can actually see..I have high Hope's for 23&me for the future.",
#    'reviewId': 'gp:AOqpTOFG5A7HIB1nD9ghI7Y7IbRwVlq18emUird5J1_NZ410h1WFau6roYe89sUow38cPeGrMKAluOjVKoqVGb0',
#    'version': '4.76.2',
#    'authorId': '103952317704919928876',
#    'author': 'Jacob Hawkins',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-9LDzf7LhixQ/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNwtI-o1J3S6yzyB2qJLi1-gOX8Rw/photo.jpg',
#    'timestampEpoch': 1548012874,
#    'timestamp': '2019-01-20 19:34:34'},
#   {'id': 1548347636015,
#    'rating': 4,
#    'body': 'After two weeks from my expected results day. They sent me notice that they needed a resample for my test and provided me with an new one two days later.',
#    'reviewId': 'gp:AOqpTOFnbgeYVDUwiU6vx6eeTtDioFTD9VnfxmN2QnkgLn4lT2w5-NXJBI1U43MwwNtA43xbGuEGFS8ZrduoB6U',
#    'version': '4.76.2',
#    'authorId': '109478530314967740197',
#    'author': 'Shawn Jones',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-3SewOo3vQ4A/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQN-6cb7hPBFlBcruEAdCfH5wBFWhA/photo.jpg',
#    'timestampEpoch': 1548347636,
#    'timestamp': '2019-01-24 16:33:56'},
#   {'id': 1548204818876,
#    'rating': 4,
#    'body': "so far it has been a lot of fun, but now I'm waiting on my results and curious to see what it says and how accurate it is. Excited for now.",
#    'reviewId': 'gp:AOqpTOFl4o6EjzWuUxoTzaRwXr7ckSYVssm9Rc_D1ePCr0dYO-sw0f13LkdS68bNFPDX8fVormKbbEj2yGEgumg',
#    'version': '4.76.2',
#    'authorId': '116981635766746085265',
#    'author': 'Rocky Davis',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-WRhx_gUiMOg/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQO-tx708_Jj_4hvArHNERUcckdvPw/photo.jpg',
#    'timestampEpoch': 1548204818,
#    'timestamp': '2019-01-23 00:53:38'},
#   {'id': 1548246173229,
#    'rating': 5,
#    'body': 'i russian. and it proved i am',
#    'reviewId': 'gp:AOqpTOGj3sRSQdWdXCyZSlc_jtMgxs-JYLw9X0F9YyAavQmuGN6kNHjhkR1I9lpvh7w2EUQK9oc8ZKM6odB8vOU',
#    'version': '4.76.2',
#    'authorId': '114744352325429328619',
#    'author': "Min Yoongi's Swag",
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mC381D60ZCWVSGBs5K_cUV2ytGWEheYi4jIdXUy',
#    'timestampEpoch': 1548246173,
#    'timestamp': '2019-01-23 12:22:53'},
#   {'id': 1548107858118,
#    'rating': 5,
#    'body': 'So far everything has gone smoothly without any delays! Results should arrive in about 5 days!',
#    'reviewId': 'gp:AOqpTOGDAQka9jHSvBoy5a6wASTPgq3Fr8sXcz-rGhpVhu8-DWICil4HQtfrLvoBbBXQhCIf-8XJa6YwUv-kDTI',
#    'version': '4.76.2',
#    'authorId': '112915437126994732914',
#    'author': 'Robby Jackson',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-aS0Z3BRQK8E/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNbC4gM_ctI8vI4jGC8-bcqKI4wdg/photo.jpg',
#    'timestampEpoch': 1548107858,
#    'timestamp': '2019-01-21 21:57:38'},
#   {'id': 1548542065878,
#    'rating': 5,
#    'body': 'this is so amazing i cant say enougj about it..i was adopted when i was six mo ths d..i k ow a little about my historybit this is goung to telle so much',
#    'reviewId': 'gp:AOqpTOHu6HvXqudvpogqjDW_qtEnsyjKOhTfnEc6XL41zT69-z5mdwQ_CH5FjJIfG_E4l9p6_SJu8dNrXEN2PBU',
#    'version': '4.76.2',
#    'authorId': '117455145661788090574',
#    'author': 'Elizabeth Johnson',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-Cfuqq8gZfwQ/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQMmkkP8fkajTJ4U7opyqQwmrNzIWQ/photo.jpg',
#    'timestampEpoch': 1548542065,
#    'timestamp': '2019-01-26 22:34:25'},
#   {'id': 1548557334861,
#    'rating': 4,
#    'body': 'works as described!',
#    'reviewId': 'gp:AOqpTOEBC22olD-ewJ3chFihJNZzIDlTgqn1veSG8PnCfr5ChEtb8X39iIzrvhLHMc9UePv91-4RlZZfpDbrthg',
#    'version': '4.76.2',
#    'authorId': '101908594861035236038',
#    'author': 'Kenneth Cooper',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-lKaPDCm3HyM/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQMxRwe56pDBkouf18yuq0yt1RgWQw/photo.jpg',
#    'timestampEpoch': 1548557334,
#    'timestamp': '2019-01-27 02:48:54'},
#   {'id': 1548738754286,
#    'rating': 5,
#    'body': 'This app is easy to use and it revealed to me that I have quite a high amount of neanderthal DNA!',
#    'reviewId': 'gp:AOqpTOFvgKzfI2A5FClZn2XMSqqn3147gF4yP0weYuGGLBVKiYd9-ct9g9vzc968OBjyfEd_Mgo4mz6vyapTWcM',
#    'version': '4.76.2',
#    'authorId': '116742564303520476922',
#    'author': 'Kyle Mahre',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mDoGpu_mYll-8yjrfZow0n-aZ3E_cRMMM5RQJu_dA',
#    'timestampEpoch': 1548738754,
#    'timestamp': '2019-01-29 05:12:34'},
#   {'id': 1548253147839,
#    'rating': 4,
#    'body': 'Great service! Report detailed and easy to understand. Wish it had an easy link to send data for comparison with other sites for relatives.',
#    'reviewId': 'gp:AOqpTOFhtIeyd2YQP3Jpi-vAHiOkaPmOCtBg2ybrJrEZTyKgrSoNy_-7830G2EN_7apiQqeZ-YN9VqXeON6GBRY',
#    'version': '4.76.2',
#    'authorId': '106829988609331363785',
#    'author': 'Earline Hall',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-drbgmXMf_Ts/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQPzSwFv3GC2La3NLavBVZZ6UTAZcQ/photo.jpg',
#    'timestampEpoch': 1548253147,
#    'timestamp': '2019-01-23 14:19:07'},
#   {'id': 1548177151715,
#    'rating': 5,
#    'body': "Most accurate ancestry results so far! The others I've taken never got close.",
#    'reviewId': 'gp:AOqpTOEoGczWHDlf8coE5pmPhwNBqyPY5umEv8_is0j5N4lMwSW0d27M7a0coKCs4rWFJVXq07AawDD_0wX-vzA',
#    'version': '4.76.2',
#    'authorId': '105226466070527041131',
#    'author': 'Cheshire Cat',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAI2yLsgUTvs3Sb4IzinzyCgg_z4hh1jRNUcPCnxw',
#    'timestampEpoch': 1548177151,
#    'timestamp': '2019-01-22 17:12:31'},
#   {'id': 1548716368680,
#    'rating': 5,
#    'body': '1/28/19 update more stable than last so far',
#    'reviewId': 'gp:AOqpTOHzRYGbDj0UV5MF3ehvf0iqAf6JiP_1TJyL55zRO6lX-SsDCcXpg0pNQrBtquY8g8YZhFlpRPrIndvxSm8',
#    'version': '4.77.0',
#    'authorId': '111021545683362505039',
#    'author': 'MADD Cat',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCHaYsuK9Bd0kAU5uDm7AcjMoQUdhqVtaYQgO5e',
#    'timestampEpoch': 1548716368,
#    'timestamp': '2019-01-28 22:59:28'},
#   {'id': 1547998167805,
#    'rating': 5,
#    'body': 'GREAT DNA Mapping! As more people joined the results have become even more accurate.',
#    'reviewId': 'gp:AOqpTOFYX83obxzLCYkdYkHFZ01-U4tzNH0C4XFUD0Yhv-4rDbr9UvIiUKpZXCVMSpsifi5tF3CoUqyb6GY_VA4',
#    'version': '4.76.2',
#    'authorId': '102276322393762741693',
#    'author': 'Ryan Shoars',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-X3NCXNLKH2g/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNkufiywnDFJDdHtGtLbnzC8lI_Xw/photo.jpg',
#    'timestampEpoch': 1547998167,
#    'timestamp': '2019-01-20 15:29:27'},
#   {'id': 1548816792686,
#    'rating': 5,
#    'body': 'works well',
#    'reviewId': 'gp:AOqpTOHHvNqryV3OLeARw6_4y3wLcIEIvAB3eZEfCiEZZgfxLPFfVyiw8rZwTuFFfY7huXwM-gi3VEfjIIjsa9Q',
#    'version': '4.77.0',
#    'authorId': '107966114792543929032',
#    'author': 'Dylan Canavan',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAAETpdUSLD3B8cPbzvS3mMdAnWJK_Lg1YC5wd9kw',
#    'timestampEpoch': 1548816792,
#    'timestamp': '2019-01-30 02:53:12'},
#   {'id': 1548344146962,
#    'rating': 5,
#    'body': 'App works great, very helpful in understanding DNA and how it all works. A lot of nice features.',
#    'reviewId': 'gp:AOqpTOH8zRH_rFE6m7bH5111bZnXuxk01Z0eZbpCKTlCT0l8MEDeYgowsUhCffH7Bm6huJT2rg3qumu2s7McOWQ',
#    'version': '4.76.2',
#    'authorId': '111598993044864473791',
#    'author': 'Scott Lewis',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBiKmcYefIzNj4wtMCLtg2VN_1kQZ3OzCwl3DSsnw',
#    'timestampEpoch': 1548344146,
#    'timestamp': '2019-01-24 15:35:46'},
#   {'id': 1547944365836,
#    'rating': 1,
#    'body': 'will rate again if the app ever opens and works',
#    'reviewId': 'gp:AOqpTOETa1NsughiWh6_Mvuh0JblShuzv4HkL3PNm6lBnnLnz72Mj1ROStnYTPMDqsoPxESJW07wHARERnSC9cQ',
#    'version': '4.76.2',
#    'authorId': '100522364049631846069',
#    'author': 'Jesse V',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-oI8PJE85C88/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNJMerp5sp2BkGOKSQGDdfrDJsKXw/photo.jpg',
#    'timestampEpoch': 1547944365,
#    'timestamp': '2019-01-20 00:32:45'},
#   {'id': 1548799746032,
#    'rating': 5,
#    'body': 'easy to navigate. great!',
#    'reviewId': 'gp:AOqpTOG1Uwm3ghrphQIIMnPQ5sgcos8Dozo_31Os8wYrSw2SjyXeYQ4WLk-qo5nV2iDHHJ3UN1IuLcPR4XyoZ9I',
#    'version': '4.77.0',
#    'authorId': '114902277101435712443',
#    'author': 'Celeste Cogswell',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-djfoGbjXEh4/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNJNJT97WngwAp4sNXADUQgOEeWpQ/photo.jpg',
#    'timestampEpoch': 1548799746,
#    'timestamp': '2019-01-29 22:09:06'},
#   {'id': 1548349517481,
#    'rating': 4,
#    'body': 'Simple, intuitive app, i appreciate that it is not overly complex, updates and the time line are cool features',
#    'reviewId': 'gp:AOqpTOF2WcZIjPGIxUNhusY5M3d0xWT5a7cKSU_KFEgzkDARNIZorwEfXkg27rUyK7zzXMpoB5wTUK2CUzkS8g4',
#    'version': '4.76.2',
#    'authorId': '108577169862294835546',
#    'author': 'Dan Duffy',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBO7x8GObSuDQJA4yC00A8h76orG0LjxMFkcwqoRg',
#    'timestampEpoch': 1548349517,
#    'timestamp': '2019-01-24 17:05:17'},
#   {'id': 1548349653563,
#    'rating': 5,
#    'body': "Very nice I love it. It's user friendly and keeps you informed.",
#    'reviewId': 'gp:AOqpTOFk5t4TIJ7yCFNZvhZOxY9MGmkWL__V7JcaQDEOT53GwZqgS_B3lhZGP1xnojGIoKu2PIqOyrI4YhQTSYI',
#    'version': '4.76.2',
#    'authorId': '116704239327025030287',
#    'author': 'Andrew Wilson',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mByXi078grze0cGLr3Q5wir3B91GbJYateebrEmzQ',
#    'timestampEpoch': 1548349653,
#    'timestamp': '2019-01-24 17:07:33'},
#   {'id': 1548764683671,
#    'rating': 5,
#    'body': 'so easy to use',
#    'reviewId': 'gp:AOqpTOEQOmLCb23likMnS6bg26nRv0Lb8F6gt2wY26Pz7K3xHtNqTD38kIhsUle8y0NjNLSivD7F0NlsIqoGQQo',
#    'version': '4.77.0',
#    'authorId': '103933891934055420545',
#    'author': 'Heather Johnson',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBg48uHs1x0WdaUpEfNmGCu8pzbinffyyLlTN60-fI',
#    'timestampEpoch': 1548764683,
#    'timestamp': '2019-01-29 12:24:43'},
#   {'id': 1548795437020,
#    'rating': 5,
#    'body': 'great for DNA testing',
#    'reviewId': 'gp:AOqpTOG06GR3JfOUgjpwGrt3BaXiZW0Rg8gjXBDf3WiCEGakY07W_ReFFUVS2pP03aN0EEU9Uj1vz1h4HxbssQQ',
#    'version': '4.77.0',
#    'authorId': '106945531934556505425',
#    'author': 'Kristin Flemming',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mDLgCAZKST7-otcigJYhZiOnKuJB4v1gcn_IPQe8Q',
#    'timestampEpoch': 1548795437,
#    'timestamp': '2019-01-29 20:57:17'},
#   {'id': 1548180486133,
#    'rating': 5,
#    'body': 'Everyone should have this test.',
#    'reviewId': 'gp:AOqpTOHqRDZAfAdQ0T48rnqLlWyN_Wmji4Se4E_bKeCfxD1k1Cl0dpHKv48X4LQawkFmsOyXxUGBh-rRwZQ4FPM',
#    'version': '4.76.2',
#    'authorId': '102693248592834470043',
#    'author': 'Mike JMRSR',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-Y7BDoXY01ms/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQPb8vusM1VUMr4O9J0L-ek1nYsaUA/photo.jpg',
#    'timestampEpoch': 1548180486,
#    'timestamp': '2019-01-22 18:08:06'},
#   {'id': 1548721005876,
#    'rating': 3,
#    'body': 'leaving a 3 star for now doing a test from ancestry and going to compare the results',
#    'reviewId': 'gp:AOqpTOFGLhFKsRc7HFJKuTEtvMU2oc9nriFs7DlVYyZ6R2uSpUIyMU4VcKOZf29KwWL5HAUnKp2CBDEKdN_iwTE',
#    'version': '4.76.2',
#    'authorId': '104068359729083085113',
#    'author': 'Kevin Paitsel',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mA3Y9eXFOLGpUplFOi7xBlch1187HoBjUkGt4nlPQ',
#    'timestampEpoch': 1548721005,
#    'timestamp': '2019-01-29 00:16:45'},
#   {'id': 1548568603582,
#    'rating': 5,
#    'body': 'it seems fairly informative. excited to get my own results back',
#    'reviewId': 'gp:AOqpTOEEvz7Xi-DWF9L_84lEH5OwG4AIl9Dk5Dg3JTdIkMTxiU0tO7EoIHA5EwV4waOjzXMTVTbyUKfZ9udtBg4',
#    'version': '4.76.2',
#    'authorId': '105892621101007669637',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-GyLbAFjQnGk/AAAAAAAAAAI/AAAAAAAAAAA/y9d2hjjEr44/photo.jpg',
#    'timestampEpoch': 1548568603,
#    'timestamp': '2019-01-27 05:56:43'},
#   {'id': 1547946937649,
#    'rating': 3,
#    'body': "Don't receive messages on the app. Other than that, it's great",
#    'reviewId': 'gp:AOqpTOEZYF3Yo7rejy4TdOqMq_d21Ru8CrPVYvG5D6o0igRCQlGCDYFz5gU6LVucKMB0469osFUXXj2NC9y6jLo',
#    'version': '4.76.2',
#    'authorId': '100623109505111820710',
#    'author': 'Jims Balls',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-02o3pXkvMls/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNKtdR7SWXmc49N5UuSIPO__Eolog/photo.jpg',
#    'timestampEpoch': 1547946937,
#    'timestamp': '2019-01-20 01:15:37'},
#   {'id': 1547934499760,
#    'rating': 5,
#    'body': 'Great. Excited for seeing more detailed reports on where my ancestry came from.',
#    'reviewId': 'gp:AOqpTOE8nZozo4ajO5MZvek0uQdRGBEkvH-GVpdDD9Rv3CRrYhRhuhgYDpfGvaYfrb_zZmFUtgLiV7V5dxxLijc',
#    'version': '4.76.2',
#    'authorId': '112740589931821833471',
#    'author': 'Gerah H.',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBrPSkPmjrgpadIniLm4t6Xh7_2rKyvikREeFigPQ',
#    'timestampEpoch': 1547934499,
#    'timestamp': '2019-01-19 21:48:19'},
#   {'id': 1548146886409,
#    'rating': 5,
#    'body': 'I am interested in having names of as many ansterers as possible.',
#    'reviewId': 'gp:AOqpTOFApC9jFE1CBbhLYYaWcl6w4oWDNyy37iyAeE0MYqfPf8mI-ui295L_GYTwnWRumjC453v7W7k4eR0xRMM',
#    'version': '4.76.2',
#    'authorId': '113840534816031338985',
#    'author': 'Sandra Nelms',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-G5bPHB4CAT8/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQN5hMVhMcswkQg3oXA_g7pcnyvDEA/photo.jpg',
#    'timestampEpoch': 1548146886,
#    'timestamp': '2019-01-22 08:48:06'},
#   {'id': 1548170844743,
#    'rating': 5,
#    'body': 'Pleasing, easy to use and access format. Well done!',
#    'reviewId': 'gp:AOqpTOGTnKQi7WTp1IuwxWH8KlVkriyrDfByMsPrser0PhzZqo1eCIw1c1u3I7sWuN2pOvRQKkZpLyT9tQ2Qi28',
#    'version': '4.76.2',
#    'authorId': '110477418098181945579',
#    'author': 'Shiori Hatagawa',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBeZrzAabRSdSNg14-C0Cp3jhVJQQ0XSLxvWyQ2GQ',
#    'timestampEpoch': 1548170844,
#    'timestamp': '2019-01-22 15:27:24'},
#   {'id': 1548448269284,
#    'rating': 5,
#    'body': 'Simple, clear interface. Information is displayed in a easy to read manner.',
#    'reviewId': 'gp:AOqpTOGmmsznUXmywGR10HGdrRTyAsI84q7QdytcqyLUjWF81NEl61mFquDLqIFvqGjXdsEYj6xyWrbbXjfFgyw',
#    'version': '4.76.2',
#    'authorId': '109712502365294259140',
#    'author': 'Kevin Beck',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCvOMJA8yi3tuWq476yE4H4RiaE_g9l43hpo5Wg',
#    'timestampEpoch': 1548448269,
#    'timestamp': '2019-01-25 20:31:09'},
#   {'id': 1548463921118,
#    'rating': 5,
#    'body': 'easy to use, so much information at my fingertips',
#    'reviewId': 'gp:AOqpTOGJeDxIobzUTTiXhorme6JgespGkF2dQJ6_3fqxl57tZLO2w5dv3aLOwNm5K42XCi0OWSY3WwKvZeG_Cjc',
#    'version': '4.76.2',
#    'authorId': '112509158605836919937',
#    'author': 'Frizzle Frizzle',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAv-wBCMN955ioZ-QmMXf-AUJFGRMptYvqTgN-kEA',
#    'timestampEpoch': 1548463921,
#    'timestamp': '2019-01-26 00:52:01'},
#   {'id': 1548237765599,
#    'rating': 5,
#    'body': "This is the best dating app I've ever used!",
#    'reviewId': 'gp:AOqpTOF5uyo-x3yIqV6pjh3ZC19UnkeLJbtn0ay_anyyRsBN-egPAMUu9I6zvh4i8KTHYCbDaDVJKlI0xKo3Tkc',
#    'version': '4.76.2',
#    'authorId': '101147282682478643061',
#    'author': 'NIck Cross',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCl_q2mv0i69_jbifMUF3ZRCyGKNbOKSFgNeMi9Vg',
#    'timestampEpoch': 1548237765,
#    'timestamp': '2019-01-23 10:02:45'},
#   {'id': 1548200076130,
#    'rating': 5,
#    'body': 'Good app. respectable company. very interesting, and informing.',
#    'reviewId': 'gp:AOqpTOHWHWV5E3Ddk5RD8SwP5sGykHZIChCWBpeFJXg3FO4rc-sYeaxB82drCjI-QnVE5hWlH80Bx90fORWTKiA',
#    'version': '4.76.2',
#    'authorId': '108716599329471692450',
#    'author': 'Dave Lawler',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mC_erSHubQ8HkZtcPumyWP5dLS_0lVFWnYWXuJKOg',
#    'timestampEpoch': 1548200076,
#    'timestamp': '2019-01-22 23:34:36'},
#   {'id': 1548433381349,
#    'rating': 5,
#    'body': 'Love the app very easy to use and very informative.',
#    'reviewId': 'gp:AOqpTOH2ZLGIgpp1-adhI0QawTfhVEH2KwTGH9LeW-ptKgVcsS5taRHUMLsjvKEqCx2ZsbG1Uaq6XU4gu5kRQgU',
#    'version': '4.76.2',
#    'authorId': '104472409984123957673',
#    'author': 'Llasmin Ochoa',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCezwl53egPQQvab4EOEPBlrku3sjMPMLOMS06uSQ',
#    'timestampEpoch': 1548433381,
#    'timestamp': '2019-01-25 16:23:01'},
#   {'id': 1548430975614,
#    'rating': 5,
#    'body': "it's sort of handy looking for your genes",
#    'reviewId': 'gp:AOqpTOF7wIynlFyeZOX850WX4L9CkxRhhSeEahZ2GMI4MAKsSQ0S-WIpQ0Z1tIheQ_tx5k1jTNz9M2cdVjdecHM',
#    'version': '4.76.2',
#    'authorId': '117350981234951939607',
#    'author': 'linda lindsey',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCnv0p_ZqeIpDN6Rs6_Zx_cOfBK0BYAQFsE4XNS',
#    'timestampEpoch': 1548430975,
#    'timestamp': '2019-01-25 15:42:55'},
#   {'id': 1548702492439,
#    'rating': 5,
#    'body': 'i love to learn about our family history.',
#    'reviewId': 'gp:AOqpTOGdQefe16uYUCKyJAOwqqzZxovECLfd9G52EARmNFCPheJH37C4Y7F1j7rr9mhZh8II55f0Zd9dKCmzjgg',
#    'version': '4.76.2',
#    'authorId': '104419082076651644838',
#    'author': 'Tom Bosse',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-wWIRS7IscRk/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQO2erTKt6Tr1Sy-C3lu9lj5fuGMuA/photo.jpg',
#    'timestampEpoch': 1548702492,
#    'timestamp': '2019-01-28 19:08:12'},
#   {'id': 1548265840928,
#    'rating': 5,
#    'body': 'Pretty amazed, how accurate they are.',
#    'reviewId': 'gp:AOqpTOFMyV9e7Wa4cE7jbAYOkksFOPrmg5cEaZh46kX6CyYtXjxpsjJeCL7SvS0btvSyXMvLqa9L3M5BB0j5Dlc',
#    'version': '4.76.2',
#    'authorId': '104542373201861570805',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBdXqxPOgUaEnK-nexitKN82SOYD2o9AxVlXKDr0A',
#    'timestampEpoch': 1548265840,
#    'timestamp': '2019-01-23 17:50:40'},
#   {'id': 1548249311505,
#    'rating': 5,
#    'body': 'great app works perfect!',
#    'reviewId': 'gp:AOqpTOFr4nFlW_LAVeoOrXODSATdJFtUy2oJxj9xxpTiyLrhb1aOe8k_O_hb7oOwBCxEzoCDAJcAf_4Ubav8cyI',
#    'version': '4.76.2',
#    'authorId': '102831024997022552328',
#    'author': 'Wayne Baker',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-bpH9UWyRO-k/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQP24neK62YIQtEMB8hraDKHSlcsIw/photo.jpg',
#    'timestampEpoch': 1548249311,
#    'timestamp': '2019-01-23 13:15:11'},
#   {'id': 1548201870298,
#    'rating': 5,
#    'body': 'love this app, very imformative.',
#    'reviewId': 'gp:AOqpTOFcd2j5zXNVJhi-MekLDHr7WsGMKHlLbWChITvzDtBOpcCw8mZoydzvUK9VDMUQEGjEzcJPQIHXPJuRNdg',
#    'version': '4.76.2',
#    'authorId': '101097797814146802386',
#    'author': 'Sherry Smith',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mDoHI9ZQNOB91zMaYTduujEL6TWFX7lsm34Qwjomd4',
#    'timestampEpoch': 1548201870,
#    'timestamp': '2019-01-23 00:04:30'},
#   {'id': 1548560999418,
#    'rating': 5,
#    'body': 'Fascinating stuff. Highly recommended',
#    'reviewId': 'gp:AOqpTOHK9qE0DxT2lg0M1o2fCapCZzQWdp4QrzGBaevTmMDBgdAghLtjUbCfxD_0Z896kwqkMJeS375GSzOqVbM',
#    'version': '4.76.2',
#    'authorId': '109741196218379277916',
#    'author': 'Eric Foss',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAP5-cUjZMjJV3DCmwVM_LLXfNEElxNDeZtmPtn',
#    'timestampEpoch': 1548560999,
#    'timestamp': '2019-01-27 03:49:59'},
#   {'id': 1547955144465,
#    'rating': 5,
#    'body': 'Generally, very good!',
#    'reviewId': 'gp:AOqpTOH9qWZzHhLkTVegjGLl0uO9THfY2iWf7utj79YrkkLG9OU_KoKFmwwENf5cUHI4llIBrSqdhE8HEDHKas0',
#    'version': '4.76.2',
#    'authorId': '114352781060130179926',
#    'author': 'Debbie Collett Griggs',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-eHB1wOk-l90/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQOXt862y6hQmC_4e4WAg0HaP5whWQ/photo.jpg',
#    'timestampEpoch': 1547955144,
#    'timestamp': '2019-01-20 03:32:24'},
#   {'id': 1548217765163,
#    'rating': 5,
#    'body': 'Easy to use and to compare.',
#    'reviewId': 'gp:AOqpTOE5I8zqeyO7Vr9UXWhEinh77bk1ORvqNXgO4_oYI52NEWQs8kKwHqNXvXvKKzLnu83CGkPaLQRKwS_jd88',
#    'version': '4.76.2',
#    'authorId': '116896078159944606017',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-Prq797CtKyE/AAAAAAAAAAI/AAAAAAAAAAA/r7ye4EhCna0/photo.jpg',
#    'timestampEpoch': 1548217765,
#    'timestamp': '2019-01-23 04:29:25'},
#   {'id': 1548130659791,
#    'rating': 5,
#    'body': "I'm happy I did it",
#    'reviewId': 'gp:AOqpTOHVEqGGrOJzQjcGF61RqHuMvCVKp0Yg-vygGwFK4vByeRX4a4La0a-VLqSMNJv7nZij1PvVQWuVW6A-A0w',
#    'version': '4.76.2',
#    'authorId': '106292409204199661226',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAu1vHmAwmKTG5imzH-mt2xG8ckbqNGXtWig3bPRQ',
#    'timestampEpoch': 1548130659,
#    'timestamp': '2019-01-22 04:17:39'},
#   {'id': 1547941161128,
#    'rating': 4,
#    'body': 'great souce of information',
#    'reviewId': 'gp:AOqpTOGUSt0aFc0fJgD_AUj4fE7sLKQWBGcdGuXptpTDT8sETvW2LgiUo_Eq7GxTMkZL-sUBDSpv8VGssxLP3tQ',
#    'version': '4.76.2',
#    'authorId': '101012210840218607326',
#    'author': 'J ACE',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-c0zncoyiuxs/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQN12WYRXEkyx7IIDzcSssMnf2tv1w/photo.jpg',
#    'timestampEpoch': 1547941161,
#    'timestamp': '2019-01-19 23:39:21'},
#   {'id': 1548285841440,
#    'rating': 4,
#    'body': 'Fast easy setup',
#    'reviewId': 'gp:AOqpTOE3SmGTauUMhhNrVX3nF-WbP1FNPjXHpsqCqu7AmfClkIBwU8BeMoE9zRIM6jwJYaCdzTDmiJ7tzT13PTg',
#    'version': '4.76.2',
#    'authorId': '110033813405843955279',
#    'author': 'Anthony Hicks',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAdrSp7FDkz1WvJ72-AVTpzqkUBbIH1u6tNFZhzmA',
#    'timestampEpoch': 1548285841,
#    'timestamp': '2019-01-23 23:24:01'},
#   {'id': 1548704519102,
#    'rating': 5,
#    'body': 'very easy to manuver',
#    'reviewId': 'gp:AOqpTOEoxyc-NChzl6p5ede4xNhFOg1182shPE1WmaoDFa3QmggOgAZAZCbqQDrGzGM0ezq6WJne99_7sSLLgzY',
#    'version': '4.76.2',
#    'authorId': '108086898739000464502',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-4TOK16wcyls/AAAAAAAAAAI/AAAAAAAAAAA/xYan1WX_LOQ/photo.jpg',
#    'timestampEpoch': 1548704519,
#    'timestamp': '2019-01-28 19:41:59'},
#   {'id': 1548120404064,
#    'rating': 5,
#    'body': 'love it!',
#    'reviewId': 'gp:AOqpTOFKcQ2QjfcJ7OmyrHe33MXZ5qPKTYQsf13D7qBLpRRNt-Hs2QL0jNP120QeAGOxAOdD75GYrKrT0nyXkqs',
#    'version': '4.76.2',
#    'authorId': '109098280244020953647',
#    'author': 'Mich Google',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-xlrP4nnXAL0/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNYonUfP3fPh1tC2kPGtvsydSNObQ/photo.jpg',
#    'timestampEpoch': 1548120404,
#    'timestamp': '2019-01-22 01:26:44'},
#   {'id': 1548453445372,
#    'rating': 5,
#    'body': 'love it!',
#    'reviewId': 'gp:AOqpTOG0EHg6FQ7wiOq8PCCrIsfCyHOGqGiHP6hSV5ahapeEtx73qwmLlR8AmTPL23iiNNN_PnC3i4q5mtqd5MA',
#    'version': '4.76.2',
#    'authorId': '111338077073879351570',
#    'author': 'Susana Morales',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-yPSxfKzWE8c/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQMJq4VwhaVNkWbXwNACJEYJZdf3AA/photo.jpg',
#    'timestampEpoch': 1548453445,
#    'timestamp': '2019-01-25 21:57:25'},
#   {'id': 1548632721516,
#    'rating': 5,
#    'body': 'awesome!',
#    'reviewId': 'gp:AOqpTOGD9aIjnQANG3RUpW301sVPoM6vIn_s1m3XLdb7kCj7OiK3MIecd8aU7AarH_-5Da0EVLEtEkEhVN-q2Nw',
#    'version': '4.76.2',
#    'authorId': '112669170596131069035',
#    'author': 'Joseph Tavarez',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mD0MMwIF1J_Z7bJ4qtwFNnGJYFeiAiPPvIQw-mlog',
#    'timestampEpoch': 1548632721,
#    'timestamp': '2019-01-27 23:45:21'},
#   {'id': 1548036241655,
#    'rating': 5,
#    'body': 'love it !',
#    'reviewId': 'gp:AOqpTOEvkTNPGBTXRZLkrtO050q3xHfPxPis-GZerJ08CGBkXQwypqU9xdcL5PYsfCayVYG4IbDoPQ7tIT40N_8',
#    'version': '4.76.2',
#    'authorId': '107410793943172857319',
#    'author': 'Erica Farmer',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBdDMBccToaHRNOOObS3gAciegHDodSsRtW494rRQ',
#    'timestampEpoch': 1548036241,
#    'timestamp': '2019-01-21 02:04:01'},
#   {'id': 1548039911850,
#    'rating': 5,
#    'body': 'Great App',
#    'reviewId': 'gp:AOqpTOFzHiqOIDmPrr8mE4do__D7HzBekD2w9blVC1Jqu117XG4EWiuh1r1uMcWp0vdT1yHCrC28WMooBVOwpE0',
#    'version': '4.76.2',
#    'authorId': '115668967585594156203',
#    'author': 'Mike Madine',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-8sso4dcV2Vs/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNZnKT2Z0JUoFVuEzb0r4EkUH3RSw/photo.jpg',
#    'timestampEpoch': 1548039911,
#    'timestamp': '2019-01-21 03:05:11'},
#   {'id': 1548008991372,
#    'rating': 5,
#    'body': 'Works wonderfully',
#    'reviewId': 'gp:AOqpTOEw4t5nGfWyZGzUNsdygSSGBQH34tg2zQQswMR7BmRl09geBHKpHcXRAcDLSE0lD0ucuceG563_Qc_eRDI',
#    'version': '4.76.2',
#    'authorId': '102820787230116589710',
#    'author': 'zackery blair',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBzp7G8rhidNen1CrRaM46ORIDhDI10_Q7MQJK0',
#    'timestampEpoch': 1548008991,
#    'timestamp': '2019-01-20 18:29:51'},
#   {'id': 1548439128829,
#    'rating': 5,
#    'body': 'very cool',
#    'reviewId': 'gp:AOqpTOGBQoCoxxHuvrwIMjoPKG54nKO7i5diDKZx37OwxGY_87sgf0SSfH__WKu_4M3ZCunfVCHn_fvbeVbRPCo',
#    'version': '4.76.2',
#    'authorId': '115993874077604700300',
#    'author': 'Virginia Travale',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAeeG9hAGN4QHu0uWO6y78KBQxbvkzYFdjA83U6',
#    'timestampEpoch': 1548439128,
#    'timestamp': '2019-01-25 17:58:48'},
#   {'id': 1548301588554,
#    'rating': 5,
#    'body': '5 stars',
#    'reviewId': 'gp:AOqpTOFBsBzyP1fzQ5NyROgJlkLwz0m-RnfzfvQCS1q_5JpX2WH_pCcC-0MDbA0CVg8B_wqGIoBde38thy1Dt9U',
#    'version': '4.76.2',
#    'authorId': '109073510225967220418',
#    'author': 'Paris Vapaille-Watson',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCN9HzazZr9_G9r7bZoLWMou3IiVOfIh_GezqqFxA',
#    'timestampEpoch': 1548301588,
#    'timestamp': '2019-01-24 03:46:28'},
#   {'id': 1548469514983,
#    'rating': 4,
#    'body': 'love this app',
#    'reviewId': 'gp:AOqpTOHvDCVzy2IB7LT7acKJ_xG27zbtHnbZe5B7XKp8ofRWsZ27LwLECh_G_4MBoOBrOb34Jzpa7lEw2iiwfZ0',
#    'version': '4.76.2',
#    'authorId': '117187061843121340464',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-jL7qXZySOWc/AAAAAAAAAAI/AAAAAAAAAAA/SMeeQpRS1T4/photo.jpg',
#    'timestampEpoch': 1548469514,
#    'timestamp': '2019-01-26 02:25:14'},
#   {'id': 1548635078932,
#    'rating': 4,
#    'body': 'great app',
#    'reviewId': 'gp:AOqpTOG_A4bBap_czKUUclW5Tlk-R78NV78NsFkYBTsKZ1mw_EMHGiKcn6mo1ljDh87V6x8kp-0Ar72n_4zjYwM',
#    'version': '4.76.2',
#    'authorId': '109854804765132843517',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAjny5vF0_lRDbQU_XUT3wU9oxU8F8rjXfJXraLkGM',
#    'timestampEpoch': 1548635078,
#    'timestamp': '2019-01-28 00:24:38'},
#   {'id': 1548389714240,
#    'rating': 5,
#    'body': 'i love this',
#    'reviewId': 'gp:AOqpTOGLDRVjTHQcjD6uU3smXlNAt8iOoMMu6H9xo82cQ8yCQPHGn0VJi9I8oSK7AErdL3LsHLfdUcb5qrZIu3o',
#    'version': '4.76.2',
#    'authorId': '109849616514702163912',
#    'author': 'Steve Reding',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mD45kDALrVFTB10zbOJ-OVOnaixhs5ffhQ6SSpsNw',
#    'timestampEpoch': 1548389714,
#    'timestamp': '2019-01-25 04:15:14'},
#   {'id': 1548574244123,
#    'rating': 5,
#    'body': 'Good',
#    'reviewId': 'gp:AOqpTOEUvaA82cRcZvkuL3qDEfd7y8npmlejDLTerKlJfogwcNUn1bGpJexxSCfHIWD4-7JBEgGk4QDrtW41n98',
#    'version': '4.76.2',
#    'authorId': '116889506854167772983',
#    'author': 'Eric Hansen',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-oqOlokGEhKo/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQOO3vLbh4Gh1DVPG6EHnzBmQ0mnoQ/photo.jpg',
#    'timestampEpoch': 1548574244,
#    'timestamp': '2019-01-27 07:30:44'},
#   {'id': 1548597692581,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOHWueUuvfzBX1BqxjPs3m7u23RVzAvVmiAfaLiue8jJiUw12xoAnTS4546HgDlmgFbkcp-WerfDKyeWonE',
#    'version': '4.77.0',
#    'authorId': '102942274843206542732',
#    'author': 'Armando Gallegos',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAKK8vKKYOop_wvwcm8Uy-vIN3gq9qCXrMYFwr5',
#    'timestampEpoch': 1548597692,
#    'timestamp': '2019-01-27 14:01:32'},
#   {'id': 1548652298143,
#    'rating': 4,
#    'reviewId': 'gp:AOqpTOFC07i64zv0HoUXYRBwAkGUjvUyn4jE6cAhTkDKpNmCS8LJpXR7YBDzJGMNuFt7tGxJmUS9XU_IKpDX6lw',
#    'version': '4.77.0',
#    'authorId': '117697205902034875508',
#    'author': 'Freddy Moreno',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCWVV3m1Dfv-CM59hnDLnHKujH2ghaH_or0chYR6is',
#    'timestampEpoch': 1548652298,
#    'timestamp': '2019-01-28 05:11:38'},
#   {'id': 1548709500371,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOHKP9zI7YqbA2jAxBou_43TXD98YQnSiM-KD8iE_hbyvF50XGF0wbNiLLIZtTGFuvUnkI7vnPUsovkmJXk',
#    'version': '4.77.0',
#    'authorId': '117692536323474012449',
#    'author': 'Robert DiRisio',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAIatw77_gUwuSBWbSCkCbV-ZgcF1dUZrwS2tkBkA',
#    'timestampEpoch': 1548709500,
#    'timestamp': '2019-01-28 21:05:00'},
#   {'id': 1548715611269,
#    'rating': 3,
#    'reviewId': 'gp:AOqpTOE6_t7U86aXWXWYnxj8BZNK1vcUcqakL8hJufKHtUZzvUrbDo16172E14TFe6o-hbwBmaKCj5BvUDDnZ3M',
#    'version': '4.77.0',
#    'authorId': '107774405393717882524',
#    'author': 'Matthew Halliwell',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAhBCBnVpVWhyoNjmM104c7YMaZUw7UW5nigg3sxv0',
#    'timestampEpoch': 1548715611,
#    'timestamp': '2019-01-28 22:46:51'},
#   {'id': 1548712510374,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOFu6Z8ei2dxybV9WrAdzNMVjWfMMrLw5SRWQYHDSTRv3czLKjEu0HlrrI_ZtsxdmSPTPO-M3SyeWmNB6SQ',
#    'version': '4.77.0',
#    'authorId': '116709959906458557640',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-uXfhYUWmjGA/AAAAAAAAAAI/AAAAAAAAAAA/Qehhusf1dqM/photo.jpg',
#    'timestampEpoch': 1548712510,
#    'timestamp': '2019-01-28 21:55:10'},
#   {'id': 1548716738687,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOGZAoYp0tK4LgVZQqurJWFpPGdRo_-UeLSnjVPPA9IgCd_b5v8b5_yqpbCQqVMRHTa2GSeWTiYNlW_vnv4',
#    'version': '4.77.0',
#    'authorId': '103220202208393119420',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCjxICSJBMdrvM-fBmaE-rXgZ0i4eESZgSx3pJS',
#    'timestampEpoch': 1548716738,
#    'timestamp': '2019-01-28 23:05:38'},
#   {'id': 1548717496833,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOH9iVlsLXBmHxGmfn777b0cMU16ER6_7zhQhYc0v8UBKA2t3f0Rwc-WJ84WYX8fzZYheqporUXghBj7LGg',
#    'version': '4.77.0',
#    'authorId': '113335227308746226301',
#    'author': 'Hecbec15',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mBTogs5XuzPAvPWUaWCHYaHcofIKRCpR9nG3kEBlA',
#    'timestampEpoch': 1548717496,
#    'timestamp': '2019-01-28 23:18:16'},
#   {'id': 1548721218766,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOENLRk5lxNyINGuPHyPtRSWhBwsYCCUMEIa9oLci0c1dN6JfT-n2oAnnuDYk-u3_QAGIqoDR4BBhknyn_w',
#    'version': '4.77.0',
#    'authorId': '108820092681497123780',
#    'author': 'Samurai Storm',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mAUohGOmR8F09AAESMx3pr9gOxAfErlC_RycRT6mw',
#    'timestampEpoch': 1548721218,
#    'timestamp': '2019-01-29 00:20:18'},
#   {'id': 1548724082145,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOFZ6ywDp9Hlixb_FLUJae9rO_OWI-HPY8334mSFOcmrWmeF5qOgtL4s7PUVkHxZcNPF3Jgoi9G-AjQ3JbU',
#    'version': '4.77.0',
#    'authorId': '101791730600671158183',
#    'author': 'Joshua Rollain',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-VM_xYO7MLJw/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQOeYnRr32idAoisBKXlA4Zy8uy_wg/photo.jpg',
#    'timestampEpoch': 1548724082,
#    'timestamp': '2019-01-29 01:08:02'},
#   {'id': 1548729858939,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOHtUeOVbKwb614DxeopBVTpAjHLW2pW0GY2R7bSTiLd64YbYhu51SFwnwU5OVH8pinS1YjYSl71H1RhIWQ',
#    'version': '4.77.0',
#    'authorId': '100617272792306108008',
#    'author': 'Jereny Larry',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-mokQkafDtIM/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQOm6OmRekO1u1EalLis_o0SnsCCbQ/photo.jpg',
#    'timestampEpoch': 1548729858,
#    'timestamp': '2019-01-29 02:44:18'},
#   {'id': 1548760718051,
#    'rating': 4,
#    'reviewId': 'gp:AOqpTOFVp2HE6GVej06zDArGsAvEsWZIIqlaUJ5fKiPRbxk-VG1LZ0YgTKUg7_i26O_yMsXeo1r-mmbwOJVa1Zw',
#    'version': '4.77.0',
#    'authorId': '117862716536834050812',
#    'author': 'Miranda Dvorak',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-Lmjkh-2BSBk/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNLRiMq2FWOFgOLHtRjuKXlZ-nLvw/photo.jpg',
#    'timestampEpoch': 1548760718,
#    'timestamp': '2019-01-29 11:18:38'},
#   {'id': 1548728684515,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOEI2SybZ84hfMM7TgoTxZhfTaicQhWGvFRe7toeHJ7kJZ5UiiDZtPFfvjNXF89Mg_GjjQ8_pT1OGNJdIJo',
#    'version': '4.77.0',
#    'authorId': '115797979907249846481',
#    'author': 'Viktor Busánszki',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-teravHJ_f7U/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQN_Fp9zAtOjBtWQ3-v4VUrjySSHVg/photo.jpg',
#    'timestampEpoch': 1548728684,
#    'timestamp': '2019-01-29 02:24:44'},
#   {'id': 1548729530724,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOFLbwJrzWxXLZ_mXT8LNWprYFuEIWrFLNJVFI3XCrKAfRXM7mHAJPyNip4dyVRm4xt4_i9c5fg8cWuLCt8',
#    'version': '4.77.0',
#    'authorId': '109763718158151900117',
#    'author': 'Brandy Ann Petrick',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-VVRwnOhKgIw/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQMMgJxRey5KrpYAf9EKmUVuKu3Xiw/photo.jpg',
#    'timestampEpoch': 1548729530,
#    'timestamp': '2019-01-29 02:38:50'},
#   {'id': 1548732199015,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOFg1ZxkW4by_JTyGzUmDE8pMJqCRXNmTmwgyPV4W_NLFSpLV0GX_WukWOYjvMM6BdyjSaMEaeRg5DhYI-s',
#    'version': '4.77.0',
#    'authorId': '100322291557268052398',
#    'author': 'Gary Bauer',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mDaZqvONHZGIY9Ng7VGker5fB_HFJ1BAYCMFHZGnQ',
#    'timestampEpoch': 1548732199,
#    'timestamp': '2019-01-29 03:23:19'},
#   {'id': 1548759187100,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOEcFg9Ca72PHYk7jCXTh6NYNBJdztFVCddRKFpq9ALm3W2of28aEoktYYtcHD-vJMKeG2z72K_Ar7AXzpE',
#    'version': '4.77.0',
#    'authorId': '104020283956295085193',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-NpbPNZawEUc/AAAAAAAAAAI/AAAAAAAAAAA/B4VECDlXEzU/photo.jpg',
#    'timestampEpoch': 1548759187,
#    'timestamp': '2019-01-29 10:53:07'},
#   {'id': 1548818147888,
#    'rating': 4,
#    'reviewId': 'gp:AOqpTOG4F-sRf8ipBbtHyU8lzcYKHjMCqZ-LuhFJfE1VhGve_Q77y7GULcyG7hBtddLX0xkWYK8jqplLexM818g',
#    'version': '4.77.0',
#    'authorId': '114030640202306200181',
#    'author': 'Sebastian Nolan',
#    'authorProfileImageUrl': 'https://lh5.googleusercontent.com/-h2eeflxDY10/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNZ0xxRzjL8OsDc_xPFyvWwdJtx3g/photo.jpg',
#    'timestampEpoch': 1548818147,
#    'timestamp': '2019-01-30 03:15:47'},
#   {'id': 1548771813078,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOHHjNHJNMOLubX9TysEsbqwpj3YlutVu2ULTg7FnneLMv6GGqh3M8_KdDsOwJmn-IDCXrpVrAm_xqcimdg',
#    'version': '4.77.0',
#    'authorId': '106115874542426335393',
#    'author': 'Andrea Moesser',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/-g0pkB1c0LgA/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQOmu2LGA93Od-GY9YzylNgVxTn0JA/photo.jpg',
#    'timestampEpoch': 1548771813,
#    'timestamp': '2019-01-29 14:23:33'},
#   {'id': 1548821950994,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOGf2zIowD6rt762IDNeEJaReedEbJjAB31pGV7P0NjymXN3QhOQmyb6bq_Xxj2LCTC_czU62DBL8vTCZDA',
#    'version': '4.77.0',
#    'authorId': '115381254501288924114',
#    'author': 'A Google user',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-EP2MthFcrM0/AAAAAAAAAAI/AAAAAAAAAAA/Wgzq5JS5EuM/photo.jpg',
#    'timestampEpoch': 1548821950,
#    'timestamp': '2019-01-30 04:19:10'},
#   {'id': 1548774166063,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOHx1NUZxC_D9mjO2uhXai6dv8uVIawxFng1GuLn3J1zZk0_poZz1IsjHFFWJUTxXu9NxOSV41byzCQ7lLU',
#    'version': '4.77.0',
#    'authorId': '101754566294719084141',
#    'author': 'Cheri Allen',
#    'authorProfileImageUrl': 'https://lh6.googleusercontent.com/-r9ds7Ku68Gc/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQOKJSpAFcY82MPZfebtWHvueza_Eg/photo.jpg',
#    'timestampEpoch': 1548774166,
#    'timestamp': '2019-01-29 15:02:46'},
#   {'id': 1548780185362,
#    'rating': 5,
#    'reviewId': 'gp:AOqpTOGhzuuBXdh2FhkLQUWZ0emi8yKTGZyE0w8o0UpEmMiUGnD97ahmr5TscRxzXBZbCKtgBoDt4pJfIJ87-f4',
#    'version': '4.77.0',
#    'authorId': '105187519044715994400',
#    'author': 'Marissa Stifter',
#    'authorProfileImageUrl': 'https://lh3.googleusercontent.com/a-/AAuE7mCzYHFKj5SNbhJ3ac6h8D-wQs9VxUVy4ZArYZCVTw',
#    'timestampEpoch': 1548780185,
#    'timestamp': '2019-01-29 16:43:05'},
#   {'id': 1548800375965,
#    'rating': 4,
#    'reviewId': 'gp:AOqpTOGjSdQakyM0JpkWgjC0mynOrsaQRrhTRpcdJ_SVxBcN8YqDZEIbD3M6Mza-FoTLRjrhGhOUEHW4j3QmtEY',
#    'version': '4.77.0',
#    'authorId': '107629522325507143389',
#    'author': 'Jessica Ware',
#    'authorProfileImageUrl': 'https://lh4.googleusercontent.com/-bupXfau9HWM/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQNAcxv3hhtd6_8rr95r8veBtprS_w/photo.jpg',
#    'timestampEpoch': 1548800375,
#    'timestamp': '2019-01-29 22:19:35'}]}

# %%
# Aggregate helpful and recent reviews and 
# create a unique list of reviews for each app.

app_reviews_together = {}
for app in app_names:
    helpful_review_ids = [review['id'] for review in app_reviews_helpful[app]]
    recent_review_ids = [review['id'] for review in app_reviews_recent[app]]
    all_reviews_ids = list(set(helpful_review_ids).union(set(recent_review_ids)))
    app_reviews_all = app_reviews_helpful[app] + app_reviews_recent[app]
    app_reviews_unique = list({review['id']:review for review in app_reviews_all}.values())
    app_reviews_together[app] = app_reviews_unique

# %%
# json to tabular format.

app_reviews_tabular = []
for ix, metadata in df_metadata.iterrows():
    reviews = app_reviews_together[metadata['name']]
    for review in reviews:
        row = OrderedDict()
        row['name'] = metadata['name']
        row['id'] = metadata['id']
        #row['userRatingCount'] = metadata['userRatingCount']
        #row['avgUserRating'] = metadata['avgUserRating']
        row['title'] = review.get('title')
        row['author'] = review.get('author')
        row['authorId'] = review.get('authorId')
        row['rating'] = review.get('rating')
        row['date'] = review.get('timestamp')
        row['voteSum'] = review.get('voteSum')
        row['voteCount'] = review.get('voteCount')
        row['content'] = review.get('body')
        if row['content'] is not None:
            row['content'] = row['content'].replace('\n', '')
        app_reviews_tabular.append(row)

# %%
df_out = pd.DataFrame(app_reviews_tabular); df_out.head(2)
# Out:
#              name                        id title       author  \
# 0  23andMe Health  com.twentythreeandme.app  None  Carrie Rios
# 1  23andMe Health  com.twentythreeandme.app  None      Angie Q
#
#                 authorId  rating                 date voteSum voteCount  \
# 0  110568310443405189483       3  2019-01-22 17:56:44    None      None
# 1  104347726632168158977       3  2019-01-28 10:58:22    None      None
#
#                                              content
# 0  the learning aspect of the app it's great, but...
# 1  This app would be awesome if I could also rece...

# %%
df_out = df_out[df_out['content'].isna() == False]  # Remove reviews with no content

# %%
df_out.to_csv("data/googleplay_reviews_dna.csv")
