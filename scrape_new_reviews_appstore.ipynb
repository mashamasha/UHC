# %%
from datetime import datetime
import json
import requests
import xmltodict

# %%
with open("data/appstore_metadata_and_reviews_47apps_110418.json", "r") as f:
    file = f.read()
    data = json.loads(file)

# %%
def fetch_reviews(app_id, country = 'us', sortBy = 'mostRecent', page = 1):
    """ Get max 500 user reviews for a given app.
    
    country = default to United States (us).
    sorty = 'mostRecent'(default) or 'mostHelpful'.
    page = page number. default = 1, max = 10.
    """
    
    url = 'https://itunes.apple.com/%s/rss/customerreviews/id=%s/sortBy=%s/page=%s/xml' % (country, 
                                                                                           str(app_id), 
                                                                                           sortBy,
                                                                                           str(page))
    r = requests.get(url)
    reviews_dict = xmltodict.parse(r.text)
    
    try:  # If there are no reviews on this page, break out of loop
        reviews_list = reviews_dict['feed']['entry']
    except:
        return []
    
    reviews = []
    for review in reviews_list:
        try:
            reviews.append({'title': review['title'],
                           'author': review['author']['name'],
                           'authorUrl': review['author']['uri'],
                           'rating': review['im:rating'],
                           'date': review['updated'],
                           'voteSum': review['im:voteSum'],
                           'voteCount': review['im:voteCount'],
                           'content': review['content'][0]['#text'].replace('\n', ' ')
                           })
        except:
            break
    return reviews

# %%
app_metadata = []
# Get most recent and most helpful reviews (separately) for app (up to 500)
# NOTE: If the app does not have many reviews, the same reviews may be included in both recent
# and helpful reviews.
for app in data:
    # If the app in our previous data has no reviews, skip and remove from list
    try:
        last_review = app['recent_reviews'][0]
    except:
        continue
        
    recent_reviews = []
    print(app['name'])

    for i in range(1, 11): 
        print(i)
        new_reviews = fetch_reviews(app['id'], page=i)
        
        # Stop once we have passed thae last review we have stored (by date)
        last_review_in_new = False
        for j, review in enumerate(new_reviews):
            if datetime.strptime(review['date'][:-6], "%Y-%m-%dT%H:%M:%S") <= datetime.strptime(last_review['date'][:-6], "%Y-%m-%dT%H:%M:%S"):
                last_review_in_new = True
                break
        
        if last_review_in_new == False:
            recent_reviews += new_reviews
        else:
            recent_reviews += new_reviews[:j]
            break

    app['recent_reviews'] += recent_reviews
    app_metadata.append(app)
# Out:
# FollowMyHealth®
# 1
# {'title': 'Awesome', 'author': 'Jake 1242367', 'authorUrl': 'https://itunes.apple.com/us/reviews/id313379422', 'rating': '5', 'date': '2018-11-04T10:49:21-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Great app to keep updates on bloodworms and tests'}
# healow
# 1
# {'title': 'HEALOW does not work!', 'author': 'Texassidewinder', 'authorUrl': 'https://itunes.apple.com/us/reviews/id36324930', 'rating': '1', 'date': '2018-11-04T09:33:05-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Impossible to locate my doctor. App has significant glitches. I have downloaded, deleted, re-downloaded, restarted my iPhone repeatedly and it continuously puts me in mode to search for doctor by name. Skips the screen that allows alternative searches (by practice name, etc) and dumps me into a list of random doctors in my area.  Setting up a new account is impossible. First time users are put into a screen with user name and password with no new user setup - just lost password and username options.  Not very helpful.'}
# Healthspek - Personal Health Record & Family Health Record - Complete Medical Record for iPhone
# 1
# {'title': 'Not good and a piece of garbage!!!!!', 'author': 'Tfrog5489', 'authorUrl': 'https://itunes.apple.com/us/reviews/id505166263', 'rating': '1', 'date': '2017-08-31T18:17:56-07:00', 'voteSum': '0', 'voteCount': '1', 'content': "This is not good and this app is a piece of garbage and it's a total waste of money and time.... it's very clumsy and if you want the genentic profile you have to spend an arm and a leg on it and thank god I looked at the price before that. Dynotag is cheaper than this piece of garbage and thank stinking god I changed my email account so I wouldn't be bombarded by their stupid pathetic reps... STAY AWAY FROM THIS APP BECAUSE IT'S GARBAGE!!!!!!"}
# DrChrono OnPatient Portal
# 1
# {'title': 'Glitch', 'author': 'Tenacious 15785433', 'authorUrl': 'https://itunes.apple.com/us/reviews/id201277349', 'rating': '1', 'date': '2018-10-05T14:42:45-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Iâ€™m unable to send my dr an email. The app crashes!'}
# Teladoc
# 1
# {'title': 'Very pleased!', 'author': 'Laura Lov', 'authorUrl': 'https://itunes.apple.com/us/reviews/id553715261', 'rating': '5', 'date': '2018-11-04T07:30:49-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'So I woke up this morning with an eye infection . I was considering going to the urgent care and thought I would try Teladoc . I logged my issue and within 15 minutes a doc called me and now I am headed to the pharmacy to get my prescription.   With Teladoc I was able to save on an urgent care copay and a drive to the office.   Love the ease!   Laura'}
# The Diary Health App
# 1
# {'title': 'Not recommended', 'author': 'Gwylion', 'authorUrl': 'https://itunes.apple.com/us/reviews/id24966389', 'rating': '1', 'date': '2018-08-19T09:23:13-07:00', 'voteSum': '1', 'voteCount': '1', 'content': 'Seems to have changed how they treat your data, and how one gets access. It used to be user-focused & empowering. Now it seems like just another app to centralize control and harvest data.'}
# Emrify - Personal Health Record
# 1
# {'title': 'Bar bones app', 'author': 'Ripsnort54', 'authorUrl': 'https://itunes.apple.com/us/reviews/id180224399', 'rating': '1', 'date': '2018-05-15T16:41:58-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Cannot send medical info. Cannot enter much detail.'}
# Personal Records
# 1
# {'title': 'Great so far!', 'author': 'MLB39', 'authorUrl': 'https://itunes.apple.com/us/reviews/id39489111', 'rating': '5', 'date': '2018-09-25T23:09:37-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I’ve tried a few apps, and am annoyed with the complications of use- I don’t need bright colors, and a million icons- I want simple, track my PRs, help me grow here! This app isn’t frilly, and doesn’t need to be!'}
# UPMC Health Plan
# 1
# {'title': 'Very disappointed', 'author': 'DVT Prone Mom', 'authorUrl': 'https://itunes.apple.com/us/reviews/id130202449', 'rating': '1', 'date': '2018-09-06T11:18:59-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Loved when they previously used MyChart app and I could email my doctor and check test results without having to log into a computer.  Was wonderful to be able to access it during my lunch hour because we are not allowed to use company computers for personal business.   Now I have to wait until I get home and most doctor’s offices do not take calls after 4:00 when you have questions.   What should be made easier is not.'}
# OpenTreatment Personal Health Record (PHR)
# 1
# {'title': 'Helpful and EASY', 'author': 'John.Madden', 'authorUrl': 'https://itunes.apple.com/us/reviews/id42091812', 'rating': '5', 'date': '2015-03-15T11:43:03-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Great UI- very easy to use. Thx for a helpful app!'}
# Capzule
# 1
# {'title': 'Best app ever', 'author': '007omar alqam', 'authorUrl': 'https://itunes.apple.com/us/reviews/id186713405', 'rating': '5', 'date': '2018-10-18T10:27:02-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Perfect app'}
# Health Tracker & Manager for iPhone - Personal Healthbook App for Tracking Blood Pressure BP, Glucose & Weight BMI
# 1
# {'title': 'Like the app. However .....', 'author': 'Rustlor', 'authorUrl': 'https://itunes.apple.com/us/reviews/id127837251', 'rating': '3', 'date': '2018-05-03T21:45:56-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Wish there was a little more flexibility in the data input. Such as explaining the circumstances in more detail, adding Temperature since often after surgery all these stats are critical.   Also wish the output feature allowed for header, layout...    Overall pretty happy but hope it grows.'}
# Sanford
# 1
# {'title': 'I love the new app', 'author': 'Undiver', 'authorUrl': 'https://itunes.apple.com/us/reviews/id11967256', 'rating': '5', 'date': '2018-10-31T19:59:55-07:00', 'voteSum': '0', 'voteCount': '0', 'content': "Much better than the old app.  I'm glad I downloaded the new one.  I'm happy MySanfordChart is right there"}
# PortalConnect
# 1
# {'title': 'Needs work', 'author': 'Artist8', 'authorUrl': 'https://itunes.apple.com/us/reviews/id103967563', 'rating': '1', 'date': '2018-06-04T09:11:50-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Good idea but fails to do much, only good at updating appts and emails. Test results never appear when they should.'}
# CareSync | Care Coordination
# 1
# {'title': 'Amazing!', 'author': 'Handsnotfull', 'authorUrl': 'https://itunes.apple.com/us/reviews/id396176426', 'rating': '5', 'date': '2018-07-18T19:59:40-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'CareSync was able to the retrieve medical records for our adopted child that our agency was unable to get. The app helps me coordinate my childâ€™s care among a team of 8 specialists. Thank you for helping us keep our child healthy!'}
# MTBC PHR
# 1
# {'title': 'Wonâ€™t accept registratiom', 'author': 'texgal1749', 'authorUrl': 'https://itunes.apple.com/us/reviews/id204937785', 'rating': '1', 'date': '2018-11-01T17:48:15-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I tried to sign up and would not register. Statement:  no account exists. I will look for another app if this canâ€™t be remedied  Very disappointed'}
# bant - Simplifying diabetes
# 1
# {'title': 'Great upgrade, modern look', 'author': 'LuchoM', 'authorUrl': 'https://itunes.apple.com/us/reviews/id173125779', 'rating': '4', 'date': '2017-06-26T20:55:13-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Review update, Dec 6, 2016:  This new version looks great and it now works flawlessly with IOS10. It now syncs with the Apple Health app, instead of the Microsoft Health Vault; you can choose different times of testing, pre or post meal time. Great update.  As soon as I upgraded my iPhone 5S to IOS10, the syncing function with MS Health stopped working and gives an error message instead. This app needs updating.  Review update: June 26, 2017:  I am getting duplicate entries for every log. Why? The only difference is the occasion (post dinner v. post snack).  This seems to be a bug.'}
# Medical Wiz - Family Health Information
# 1
# {'title': 'Upgrade will not load', 'author': 'Gregg milliken', 'authorUrl': 'https://itunes.apple.com/us/reviews/id377528177', 'rating': '2', 'date': '2018-09-12T11:44:33-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I also paid for upgrade and the upgrade will not load, it just times out and I got it so I could print my information. Not happy feel like I was taken.'}
# Healthjump
# 1
# {'title': 'Health Jump not what I thought', 'author': 'Lonewolf52', 'authorUrl': 'https://itunes.apple.com/us/reviews/id188935611', 'rating': '1', 'date': '2018-03-22T18:37:08-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I thought this app was where you could go and see test results without paying for an office visit. ....... WRONG.  It gives you nothing like that.  I wish I could give it less then a one rating.'}
# YourHealthRecord Mobile
# 1
# {'title': "Don't work", 'author': 'Dan Dan radio man', 'authorUrl': 'https://itunes.apple.com/us/reviews/id300818032', 'rating': '1', 'date': '2017-01-03T15:34:47-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Could not even put in my email address. Every time I got to the ".net"  Went to my phone home screen. Tried 3 times. Too bad, I\'ll find another.'}
# MyQuadMed
# 1
# {'title': 'Endless “Verify Email on Website” Loop', 'author': 'Just Want To Post Thie Review', 'authorUrl': 'https://itunes.apple.com/us/reviews/id102909270', 'rating': '1', 'date': '2018-05-01T21:00:35-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Would be really convenient if I could actually get INTO it... even after verifying my email address it still tells me I have to complete this step on the website prior to using the app.  Looking forward to taking advantage of the app once this gets sorted out, since there is no place to contact anyone on the main website for app support.'}
# Get Your Health Record
# 1
# {'title': 'Highly recommended!', 'author': 'soccermom76.', 'authorUrl': 'https://itunes.apple.com/us/reviews/id639240110', 'rating': '5', 'date': '2018-09-28T14:32:06-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I got this app for my mother originally so she could get her Medicare records. I saw how valuable it was to her and decided to get it myself! It keeps me really organized.'}
# RaceAddict
# 1
# {'title': 'Share with Friends', 'author': 'jodidoane', 'authorUrl': 'https://itunes.apple.com/us/reviews/id507394871', 'rating': '4', 'date': '2018-07-17T09:03:41-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I love this app to help keep me straight, but I wish there was a way to share my schedule with friends'}
# MedXCom for Patients
# 1
# {'title': 'MedXCom is an awesome app!!', 'author': 'docmjn', 'authorUrl': 'https://itunes.apple.com/us/reviews/id40949970', 'rating': '5', 'date': '2013-05-18T15:58:25-07:00', 'voteSum': '0', 'voteCount': '0', 'content': "So easy to use. It is great that I can securely store my medical history and medications on this app. I love that i have my children's medical info/immunization records with me at all times."}
# WODTrackr
# 1
# {'title': 'App not working', 'author': 'Hsalaman1', 'authorUrl': 'https://itunes.apple.com/us/reviews/id85028398', 'rating': '1', 'date': '2018-05-21T01:46:45-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'App isn’t opening up'}
# Healee
# 1
# {'title': 'Problem connecting to to Healee', 'author': 'chaosdharma', 'authorUrl': 'https://itunes.apple.com/us/reviews/id193012099', 'rating': '1', 'date': '2017-09-15T15:37:50-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'App does not open. OK. Zero performance = Zero stars. Delete App. OK.'}
# Medical Wiz Pro - Family Health Information
# 1
# {'title': 'Useful', 'author': 'njspectrum', 'authorUrl': 'https://itunes.apple.com/us/reviews/id191162762', 'rating': '4', 'date': '2018-10-30T21:01:26-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Not a bad app. It could use some improvements. Like being able to take a picture or import blood reports to its area. The same for insurance cards. An area to create file folders so other reports and documents can be placed.'}
# iBlueButton®
# 1
# {'title': 'Bloatware:  DO NOT BUY', 'author': 'fmanans', 'authorUrl': 'https://itunes.apple.com/us/reviews/id334291151', 'rating': '1', 'date': '2018-05-15T15:50:11-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Frequent crashes, timeout errors on VA, Medicare, Tricare sites:  much faster going directly to the site(s) with i.d. password downloading via Blue Button option.  Lacks very important secure messaging feature required to communicate with providers regarding your medical record!'}
# I'M HOME! ®
# 1
# {'title': 'Like no other!', 'author': 'Z. Petrovich', 'authorUrl': 'https://itunes.apple.com/us/reviews/id42092744', 'rating': '5', 'date': '2014-01-05T12:43:44-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I’m Home app let me stay updated with my doctor and track recovery after a recent back injury and surgery.  Also gave me good tips for not causing damage again and gaining strength.'}
# Dyrii Journal
# 1
# {'title': 'Refund', 'author': 'EliteSparkZz', 'authorUrl': 'https://itunes.apple.com/us/reviews/id247247406', 'rating': '3', 'date': '2018-09-21T21:11:55-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Hello. I just purchased this app by accident. I didn’t know it costed 10 dollars. Can I get a refund?'}
# BCM
# 1
# {'title': 'Not happy ðŸ™„ðŸ˜’', 'author': 'Miss B. Liz', 'authorUrl': 'https://itunes.apple.com/us/reviews/id48992555', 'rating': '1', 'date': '2017-02-07T02:53:57-07:00', 'voteSum': '0', 'voteCount': '0', 'content': "Why can't I login on the BCM app using my VALID username and/or password?! Please fix this! I've had the app since 2015 and never been able to use it."}
# Microsoft HealthVault
# 1
# {'title': 'Perfect', 'author': 'nofeeagency', 'authorUrl': 'https://itunes.apple.com/us/reviews/id327374344', 'rating': '5', 'date': '2018-10-30T21:11:53-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'From a wonderful company like MS I always expect handy tools and great products. My reliance on their products is a lifetime relationship since the days of MS-DOS I been a computer practitioner using them from a blog to a multimillion deal. I get irritated on the manuals when the independent authors on their manuals indicate clears instructions on how to use the product and on the same page there are instructions for Microsoft and a couple of paragraphs with instructions for an apple product. It is a distraction and it never occurred to them to put all the instructions for apple on a chapter by itself or st the end manual. I am sure that the apple user will enjoy having their own section, without the burden to read about something that they donâ€™t understand.'}
# FitnessSyncer
# 1
# {'title': 'Exactly what I needed', 'author': 'just want to post2742', 'authorUrl': 'https://itunes.apple.com/us/reviews/id491530111', 'rating': '5', 'date': '2018-08-20T17:52:35-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Was able to sync thing that didn’t connect for a work contest. Had some issues but all in all great app'}
# Accolade, Inc.
# 1
# {'title': 'Great service', 'author': 'kkkkkkjjjjjhhhggf', 'authorUrl': 'https://itunes.apple.com/us/reviews/id747473557', 'rating': '5', 'date': '2018-10-16T14:40:59-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Best help support system there are always there wen you need there assistance thank you so much'}
# My Medical
# 1
# {'title': 'Canâ€™t sync apps', 'author': 'Cableguy49', 'authorUrl': 'https://itunes.apple.com/us/reviews/id103421367', 'rating': '1', 'date': '2018-11-04T08:32:12-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I have both iPhone and iPad versions but I cannot sync data and neither app will sync to Dropbox wastes my moneyâ˜¹ï¸�'}
# My Medical
# 1
# {'title': 'Canâ€™t sync apps', 'author': 'Cableguy49', 'authorUrl': 'https://itunes.apple.com/us/reviews/id103421367', 'rating': '1', 'date': '2018-11-04T08:32:12-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I have both iPhone and iPad versions but I cannot sync data and neither app will sync to Dropbox wastes my moneyâ˜¹ï¸�'}
# Healthspek - Personal Health Record & Family Health Record - Complete Medical Record
# 1
# {'title': "Can't Access My New Account!", 'author': 'Spend Queen', 'authorUrl': 'https://itunes.apple.com/us/reviews/id272986175', 'rating': '1', 'date': '2018-05-20T07:06:16-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I just created an account but when I tried to sign in it wouldn\'t let me.  Just like another reviewer I even hit "forgot password" even though I didn\'t.  The site said it would send me an email immediately but lo and behold, NO EMAIL!  Now, I\'ve waited five minutes, gone back to my email and found two new ones; one from Nordstrom and the other from The Outlet.  I will not be using this app so will go ahead and delete it.'}
# Medfusion Plus
# 1
# {'title': 'Hate this app', 'author': 'dd weedy', 'authorUrl': 'https://itunes.apple.com/us/reviews/id367717722', 'rating': '1', 'date': '2018-11-03T21:09:32-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'This app is awful. It sends me in circles to load Medfusion Plus over and over again. A waist of my time.'}
# higi
# 1
# {'title': 'Add Apple health app', 'author': 'jeffus3', 'authorUrl': 'https://itunes.apple.com/us/reviews/id9381723', 'rating': '4', 'date': '2018-10-25T12:05:19-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'It would be great if PB would sync to Apple health app.'}
# Sharecare
# 1
# {'title': 'My go to place for health', 'author': 'pathway4him', 'authorUrl': 'https://itunes.apple.com/us/reviews/id35551729', 'rating': '5', 'date': '2018-11-04T04:54:13-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'I like that I have one place to put all my health information including my immunizations, doctors info and any medications. The app gets better with each day as it learns about my sleep, steps and overall stress level. The new mindfulness videos and financial health parts are good as well.   Overall, I like it and want to see how it will improve over time.'}
# Aetna Mobile
# 1
# {'title': 'User and password information', 'author': '?&@$"//:;', 'authorUrl': 'https://itunes.apple.com/us/reviews/id164986537', 'rating': '2', 'date': '2018-11-04T07:07:42-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Why is it that my user name and password that I use when I access the website online does not work on the app?  App and website need more details regarding the open claims. â€œAetna requested informationâ€� and Aetna sent a letterâ€� is very ambiguous. Also when you try to view the  Letter sent, it says something like wait an hour  to view. Let the user know in more detail about what is going on!!'}
# Kaiser Permanente
# 1
# {'title': 'Appointment', 'author': 'luisp7396', 'authorUrl': 'https://itunes.apple.com/us/reviews/id927889424', 'rating': '2', 'date': '2018-10-30T02:05:52-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Canâ€™t make a appointment with the app'}
# myCigna
# 1
# {'title': 'Crashes without opening', 'author': 'Elle91030', 'authorUrl': 'https://itunes.apple.com/us/reviews/id106503681', 'rating': '1', 'date': '2018-11-04T09:02:57-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Fix the fix!!'}
# Blue Shield of California
# 1
# {'title': 'Good app', 'author': 'Mr. Joseph Martin', 'authorUrl': 'https://itunes.apple.com/us/reviews/id482418255', 'rating': '5', 'date': '2018-10-29T12:50:06-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Really easy to use'}
# MyHumana
# 1
# {'title': 'Mr KEITH GADDY', 'author': 'customers reviews from myself', 'authorUrl': 'https://itunes.apple.com/us/reviews/id243802317', 'rating': '2', 'date': '2018-10-30T17:42:32-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Need some work on the remote controls I should have a light on him and the buttons are way too low to still hold onto the remote and push the numbers for the channels and say that would be like in number one'}
# Anthem Anywhere
# 1
# {'title': 'Garbage', 'author': 'ManintheiCloud', 'authorUrl': 'https://itunes.apple.com/us/reviews/id368768767', 'rating': '1', 'date': '2018-11-04T03:12:23-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'The functionality of this app is absolutely bonkers! Trying to get the whole mess figured out is such a dawdle at this point it needs to be completely rebuilt by a competent development team.'}
# Capital BlueCross Virtual Care
# 1
# {'title': 'Awesome!!', 'author': 'obx_mama', 'authorUrl': 'https://itunes.apple.com/us/reviews/id133603254', 'rating': '5', 'date': '2018-10-02T07:51:52-07:00', 'voteSum': '0', 'voteCount': '0', 'content': 'Saved me from hours waiting in urgent care to be seen. Able to see a provider in live by room and pick up my prescription within the hour.'}

# %%
with open('data/appstore_metadata_and_reviews_47apps_110418.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(app_metadata))
